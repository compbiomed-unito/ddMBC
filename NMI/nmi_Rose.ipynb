# %% [markdown]
# # MBC (Rose) effect on NMI data

# %% [markdown]
# ## CSV preprocessing and method selection

# %%
import pandas
from copy import deepcopy
import numpy
import math
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
numpy.seterr(all='raise')
numpy.geterr()
# Out:
# {'divide': 'raise', 'over': 'raise', 'under': 'raise', 'invalid': 'raise'}

# %%
ssym_df = pandas.read_csv("ssym_analysis.csv")
for _ in ssym_df.columns:
    if str(_).startswith("runtime"):
        ssym_df.drop(_, axis=1, inplace=True)

# %%
print(ssym_df.shape)
list(ssym_df.columns)
# Out:
# (684, 132)
# ['uid',
#  'direction',
#  'uid2',
#  'ACDC-NN',
#  'ACDC-NN-Seq',
#  'Cartddg',
#  'DDG',
#  'DDGun',
#  'DDGun3D',
#  'DUET',
#  'Dynamut',
#  'Dynamut2',
#  'Evo',
#  'FoldX',
#  'I-Mutant3.0',
#  'I-Mutant3.0-Seq',
#  'INPS-Seq',
#  'INPS3D',
#  'KORPM',
#  'MAESTRO',
#  'MUpro',
#  'PoPMuSiC',
#  'PremPS',
#  'SAAFEC-SEQ',
#  'SDM',
#  'ThermoNet',
#  'ankh',
#  'cartesian_ddg',
#  'cluster',
#  'ddG',
#  'delta_kdh',
#  'delta_vol',
#  'esm1v_1',
#  'esm1v_2',
#  'esm1v_3',
#  'esm1v_4',
#  'esm1v_5',
#  'esm1v_mean',
#  'esm1v_median',
#  'esm2_150M',
#  'esm2_15B_half',
#  'esm2_3B',
#  'esm2_650M',
#  'esmif_multimer',
#  'korpm',
#  'mCSM',
#  'mif',
#  'mifst',
#  'mpnn_10_00',
#  'mpnn_20_00',
#  'mpnn_30_00',
#  'msa_1',
#  'msa_2',
#  'msa_3',
#  'msa_4',
#  'msa_5',
#  'msa_transformer_mean',
#  'msa_transformer_median',
#  'mutcomputex',
#  'pll_esmif_multimer',
#  'rel_ASA',
#  'stability-oracle',
#  'tranception',
#  'tranception_weights',
#  'code',
#  'chain',
#  'wild_type',
#  'position',
#  'mutation',
#  'offset_up',
#  'uniprot_seq',
#  'reduced_msa_file',
#  'full_msa_file',
#  'MUT',
#  'Dyna2',
#  'PopMs',
#  'TNet',
#  'ACDCNN',
#  'wt_code',
#  'is_nmr',
#  'mismatch',
#  'msa_weights',
#  'multimer',
#  'pdb_file',
#  'pdb_ungapped',
#  'position_orig',
#  'position_pdb',
#  'tranception_dms',
#  'window_start',
#  'origin',
#  'fireprot_cluster',
#  's461_cluster',
#  's669_cluster',
#  'q3421_cluster',
#  'k2369_cluster',
#  'k3822_cluster',
#  'on_interface',
#  'entropy',
#  'conservation',
#  'column_completeness',
#  'completeness_score',
#  'n_seqs',
#  'structure_length',
#  'hbonds',
#  'saltbrs',
#  'b_factor',
#  'delta_chg',
#  'to_proline',
#  'to_glycine',
#  'to_alanine',
#  'from_proline',
#  'from_glycine',
#  'helix',
#  'bend',
#  'turn',
#  'coil',
#  'strand',
#  'active_site',
#  'neff',
#  'log_neff',
#  'ddG_dir',
#  'K1566_pslm_rfa_1',
#  'K1566_pslm_rfa_2',
#  'K1566_pslm_rfa_3',
#  'K1566_pslm_rfa_4',
#  'K1566_pslm_rfa_5',
#  'K1566_pslm_rfa_6',
#  'K1566_pslm_rfa_7',
#  'K1566_pslm_rfa_8',
#  'K1566_pslm_rfa_9',
#  'K1566_pslm_rfa_10',
#  'K1566_pslm_rfa_11']

# %% [markdown]
# ### Selected methods

# %%
methods = [
 'ACDC-NN',
 'ACDC-NN-Seq',
 'Cartddg',
 'DDGun3D',
 'DUET',
 'Dynamut',
 'Dynamut2',
 'Evo',
 'FoldX',
 'I-Mutant3.0',
 'I-Mutant3.0-Seq',
 'INPS-Seq',
 'INPS3D',
 'KORPM',
 'MAESTRO',
 'MUpro',
 'PoPMuSiC',
 'PremPS',
 'SAAFEC-SEQ',
 'SDM',
 'ThermoNet',
 'ankh',
 'cartesian_ddg',
 'esm1v_1',
 'esm1v_2',
 'esm1v_3',
 'esm1v_4',
 'esm1v_5',
 'esm1v_mean',
 'esm1v_median',
 'esm2_150M',
 'esm2_15B_half',
 'esm2_3B',
 'esm2_650M',
 'esmif_multimer',
 'mCSM',
 'mif',
 'mifst',
 'mpnn_10_00',
 'mpnn_20_00',
 'mpnn_30_00',
 'msa_transformer_mean',
 'msa_transformer_median',
 'mutcomputex',
 'stability-oracle',
 'tranception',
 'tranception_weights',
]

# %%
method_types = {
 # 'uid',
 # 'direction',
 # 'uid2',
 'ACDC-NN': 'transfer',
 'ACDC-NN-Seq': 'transfer',
 'Cartddg': 'biophysical',
 #'DDG',
 #'DDGun',
 'DDGun3D':'untrained',
 'DUET':'supervised',
 'Dynamut':'other',
 'Dynamut2':'other',
 'Evo': 'biophysical',
 'FoldX': 'biophysical',
 'I-Mutant3.0':'supervised',
 'I-Mutant3.0-Seq':'supervised',
 'INPS-Seq':'supervised',
 'INPS3D':'supervised',
 'KORPM': 'biophysical',
 'MAESTRO':'supervised',
 'MUpro':'supervised',
 'PoPMuSiC':'potential',
 'PremPS':'supervised',
 'SAAFEC-SEQ':'supervised',
 'SDM':'potential',
 'ThermoNet':'supervised',
 'ankh':'seq.PLM',
 'cartesian_ddg':'biophysical',
 'esm1v_1':'seq.PLM',
 'esm1v_2':'seq.PLM',
 'esm1v_3':'seq.PLM',
 'esm1v_4':'seq.PLM',
 'esm1v_5':'seq.PLM',
 'esm1v_mean':'seq.PLM',
 'esm1v_median':'seq.PLM',
 'esm2_150M':'seq.PLM',
 'esm2_15B_half':'seq.PLM',
 'esm2_3B':'seq.PLM',
 'esm2_650M':'seq.PLM',
 'esmif_multimer':'struct.PLM',
 'mCSM':'supervised',
 'mif':'struct.PLM',
 'mifst':'struct.PLM',
 'mpnn_10_00':'struct.PLM',
 'mpnn_20_00':'struct.PLM',
 'mpnn_30_00':'struct.PLM',
 'msa_transformer_mean':'seq.PLM',
 'msa_transformer_median':'seq.PLM',
 'mutcomputex':'struct.PLM',
 'stability-oracle':'transfer',
 'tranception':'seq. PLM',
 'tranception_weights':'seq. PLM',
}

# %%
labelz=pandas.read_csv('labelz.csv',index_col='Method')
labelz
# Out:
#                                type mass_balance
# Method
# ACDC-NN                    transfer            y
# ACDC-NN-Seq                transfer            y
# Cartddg                 biophysical            y
# DDGun3D                   untrained            y
# DUET                     supervised            y
# Dynamut                       other            y
# Dynamut2                      other            y
# Evo                     biophysical            n
# FoldX                   biophysical            n
# I-Mutant3.0              supervised            y
# I-Mutant3.0-Seq          supervised            y
# INPS-Seq                 supervised            y
# INPS3D                   supervised            y
# KORPM                   biophysical            y
# MAESTRO                  supervised            y
# MUpro                    supervised            y
# PoPMuSiC                  potential            y
# PremPS                   supervised            y
# SAAFEC-SEQ               supervised            y
# SDM                       potential            y
# ThermoNet                supervised            y
# ankh                        seq.PLM            n
# cartesian_ddg           biophysical            y
# esm1v_1                     seq.PLM            n
# esm1v_2                     seq.PLM            n
# esm1v_3                     seq.PLM            n
# esm1v_4                     seq.PLM            n
# esm1v_5                     seq.PLM            n
# esm1v_mean                  seq.PLM            n
# esm1v_median                seq.PLM            n
# esm2_150M                   seq.PLM            n
# esm2_15B_half               seq.PLM            n
# esm2_3B                     seq.PLM            n
# esm2_650M                   seq.PLM            n
# esmif_multimer           struct.PLM            n
# mCSM                     supervised            y
# mif                      struct.PLM            n
# mifst                    struct.PLM            n
# mpnn_10_00               struct.PLM            n
# mpnn_20_00               struct.PLM            n
# mpnn_30_00               struct.PLM            n
# msa_transformer_mean        seq.PLM            n
# msa_transformer_median      seq.PLM            n
# mutcomputex              struct.PLM            n
# stability-oracle           transfer            y
# tranception                seq. PLM            n
# tranception_weights        seq. PLM            n

# %%
ssym_df[methods].isna().sum()
# Out:
# ACDC-NN                   0
# ACDC-NN-Seq               0
# Cartddg                   0
# DDGun3D                   0
# DUET                      0
# Dynamut                   0
# Dynamut2                  0
# Evo                       0
# FoldX                     0
# I-Mutant3.0               2
# I-Mutant3.0-Seq           2
# INPS-Seq                  0
# INPS3D                    0
# KORPM                     0
# MAESTRO                   0
# MUpro                     0
# PoPMuSiC                  0
# PremPS                    0
# SAAFEC-SEQ                0
# SDM                       0
# ThermoNet                 6
# ankh                      0
# cartesian_ddg             0
# esm1v_1                   0
# esm1v_2                   0
# esm1v_3                   0
# esm1v_4                   0
# esm1v_5                   0
# esm1v_mean                0
# esm1v_median              0
# esm2_150M                 0
# esm2_15B_half             0
# esm2_3B                   0
# esm2_650M                 0
# esmif_multimer            0
# mCSM                      0
# mif                       0
# mifst                     0
# mpnn_10_00                0
# mpnn_20_00                0
# mpnn_30_00                0
# msa_transformer_mean      0
# msa_transformer_median    0
# mutcomputex               0
# stability-oracle          0
# tranception               0
# tranception_weights       0
# dtype: int64

# %%
select_df = ssym_df[
    ["uid", "direction", "uid2", "DDG", "chain","wild_type", "position", "mutation"] + methods
].dropna()
# select_df.dropna(inplace=True)
select_df
# Out:
#            uid direction       uid2  DDG chain wild_type  position mutation  \
# 0    1AMQ_191F       dir  1AMQ_180F -1.6     A         C       180        F
# 1    1AMQ_191F       inv  1AMQ_180F  1.6     A         C       180        F
# 2    1AMQ_191S       dir  1AMQ_180S -1.9     A         C       180        S
# 3    1AMQ_191S       inv  1AMQ_180S  1.9     A         C       180        S
# 4    1AMQ_191W       dir  1AMQ_180W -3.9     A         C       180        W
# ..         ...       ...        ...  ...   ...       ...       ...      ...
# 679   5PTI_35G       inv   5PTI_35G  5.0     A         Y        35        G
# 680   5PTI_43G       dir   5PTI_43G -5.7     A         N        43        G
# 681   5PTI_43G       inv   5PTI_43G  5.7     A         N        43        G
# 682   5PTI_45A       dir   5PTI_45A -6.9     A         F        45        A
# 683   5PTI_45A       inv   5PTI_45A  6.9     A         F        45        A
#
#       ACDC-NN  ACDC-NN-Seq  ...      mifst  mpnn_10_00  mpnn_20_00  \
# 0    0.155387     0.000000  ... -15.833597   -4.753813   -5.319994
# 1   -0.179437     0.000000  ...  11.865127    4.274536    5.143872
# 2   -0.310174     0.000000  ...  -7.009702   -0.511659   -2.171657
# 3    0.150363     0.000000  ...   7.094869   -0.156843    1.406749
# 4    0.175478     0.000235  ... -16.822426   -4.945947   -5.441107
# ..        ...          ...  ...        ...         ...         ...
# 679  2.394038     3.046156  ...   1.420484   -5.640223   -5.485600
# 680 -1.785572    -1.548846  ... -13.269845   -5.804597   -5.387895
# 681  1.418397     1.558716  ...  10.233284    5.155628    5.263233
# 682 -3.439780    -3.219905  ... -12.405282   -5.616822   -5.456846
# 683  2.607126     3.225423  ...   8.944525    5.015940    4.813072
#
#      mpnn_30_00  msa_transformer_mean  msa_transformer_median  mutcomputex  \
# 0     -4.230467            -11.351413              -11.507070    -0.072907
# 1      4.086548             11.351413               11.507070     0.010589
# 2     -0.905479             -5.473701               -6.148736     0.152491
# 3      0.149925              5.473701                6.148736    -0.109291
# 4     -4.408648            -13.321842              -13.401335    -0.072507
# ..          ...                   ...                     ...          ...
# 679   -5.337170             10.376691               10.705666    -0.999981
# 680   -5.760532             -9.403118               -9.475676    -0.957911
# 681    4.256405              9.403118                9.475676    -0.999996
# 682   -5.437554            -12.561387              -13.084740    -0.915575
# 683    5.219217             12.561387               13.084740     0.279832
#
#      stability-oracle  tranception  tranception_weights
# 0              -0.365    -0.030819            -0.029796
# 1               0.110     0.030819             0.029796
# 2              -0.009    -0.015818            -0.015382
# 3               0.108     0.015818             0.015382
# 4              -0.616    -0.035233            -0.037848
# ..                ...          ...                  ...
# 679            -1.087     0.091949             0.097295
# 680            -0.303    -0.055134            -0.062423
# 681            -0.070     0.055134             0.062423
# 682            -0.849    -0.100102            -0.089689
# 683             0.243     0.100102             0.089689
#
# [676 rows x 55 columns]

# %%
train_rez = pandas.DataFrame()
for _ in ['pearson','spearman']:
    train_rez['plain_' + _ ]= select_df[methods].corrwith(select_df['DDG'],method=_)
train_rez['plain_RMSE']= [ math.sqrt(mean_squared_error(select_df['DDG'],select_df[_m])) for _m in methods ]
#train_rez
train_rez.sort_values('plain_pearson',ascending=False)
#train_rez.sort_values('plain_RMSE',ascending=True)
# Out:
#                         plain_pearson  plain_spearman  plain_RMSE
# PremPS                       0.847589        0.834067    1.046586
# KORPM                        0.696388        0.725962    1.338914
# ACDC-NN                      0.693890        0.626436    1.393952
# ACDC-NN-Seq                  0.686184        0.572426    1.389011
# mpnn_30_00                   0.669151        0.709083    2.279188
# mpnn_20_00                   0.657558        0.693754    2.420931
# DDGun3D                      0.649913        0.548728    1.407750
# msa_transformer_mean         0.643642        0.634182    5.342200
# msa_transformer_median       0.643297        0.631633    5.376427
# mifst                        0.640590        0.631589    4.822427
# Cartddg                      0.637411        0.635182    3.405207
# INPS-Seq                     0.630054        0.557573    1.446647
# mpnn_10_00                   0.628000        0.652037    2.604587
# cartesian_ddg                0.624744        0.671402    5.041773
# mif                          0.617599        0.600899    4.240144
# stability-oracle             0.617409        0.629840    1.573712
# ankh                         0.617091        0.620721    5.991157
# esm2_15B_half                0.610243        0.633714    8.924851
# tranception                  0.606895        0.608396    1.823399
# tranception_weights          0.605821        0.608293    1.823430
# esm2_650M                    0.604709        0.614023    5.654608
# esm2_3B                      0.598710        0.606196    8.046196
# INPS3D                       0.561731        0.475367    1.614918
# Evo                          0.554607        0.493212    1.561813
# esmif_multimer               0.547447        0.568851    1.828439
# PoPMuSiC                     0.501536        0.482101    1.750445
# Dynamut                      0.498299        0.448121    1.610121
# ThermoNet                    0.491120        0.418616    1.613678
# MUpro                        0.485768        0.366578    1.879253
# FoldX                        0.485111        0.509246    2.041594
# esm2_150M                    0.466041        0.469239    3.352277
# DUET                         0.432895        0.383564    1.833744
# MAESTRO                      0.432736        0.412807    1.777990
# esm1v_2                      0.429947        0.504154    3.905931
# mutcomputex                  0.420804        0.467437    1.734694
# esm1v_mean                   0.419490        0.480454    3.573549
# esm1v_5                      0.418776        0.490145    3.926035
# esm1v_median                 0.416699        0.477686    3.593399
# esm1v_4                      0.408192        0.449385    3.521259
# esm1v_3                      0.406934        0.439673    3.343533
# I-Mutant3.0-Seq              0.402840        0.403089    1.807418
# mCSM                         0.398768        0.329252    1.921095
# esm1v_1                      0.387076        0.435760    3.643741
# I-Mutant3.0                  0.384281        0.370347    1.838647
# Dynamut2                     0.382145        0.289238    1.888800
# SDM                          0.319628        0.295362    1.993101
# SAAFEC-SEQ                   0.241503        0.180890    2.088778

# %% [markdown]
# ### S461

# %%
s461_df = pandas.read_csv("s461_relabeled.csv")
for _ in s461_df.columns:
    if str(_).startswith("runtime"):
        s461_df.drop(_, axis=1, inplace=True)
s461_df.shape
# Out:
# (461, 168)

# %%
#'rel_ASA_dir'.rsplit('_',maxsplit=1)
#list(s461_df.columns)

# %%
s461_dir= [ _.rsplit('_', maxsplit=1)[0] for _ in s461_df.columns if _.endswith('dir')]
s461_dir
# Out:
# ['PDB',
#  'MUT_D',
#  'ddG',
#  'KORPM',
#  'Cartddg',
#  'FoldXD',
#  'Evo',
#  'Dynamut2',
#  'PoPMuSiC',
#  'DDGunD',
#  'TNetD',
#  'ACDCNND',
#  'DDG_checked',
#  'MAESTRO',
#  'FoldX',
#  'PremPS',
#  'Dynamut',
#  'mCSM',
#  'SDM',
#  'DUET',
#  'I-Mutant3.0',
#  'I-Mutant3.0-Seq',
#  'MUpro',
#  'SAAFEC-SEQ',
#  'DDGun3D',
#  'DDGun',
#  'ACDC-NN-Seq',
#  'ACDC-NN',
#  'INPS-Seq',
#  'INPS3D',
#  'PopMusic',
#  'SOL_ACC',
#  'SEC_STR',
#  'ThermoNet',
#  'msa_1',
#  'msa_2',
#  'msa_3',
#  'msa_4',
#  'msa_5',
#  'msa_transformer_median',
#  'msa_transformer_mean',
#  'esmif_multimer',
#  'pll_esmif_multimer',
#  'esm2_3B',
#  'esm2_15B_half',
#  'mpnn_10_00',
#  'mpnn_20_00',
#  'mpnn_30_00',
#  'mif',
#  'mifst',
#  'esm2_150M',
#  'esm2_650M',
#  'esm1v_1',
#  'esm1v_2',
#  'esm1v_3',
#  'esm1v_4',
#  'esm1v_5',
#  'esm1v_median',
#  'esm1v_mean',
#  'tranception',
#  'mutcomputex',
#  'tranception_weights',
#  'korpm_unk',
#  'ankh',
#  'stability-oracle',
#  'cartesian_ddg',
#  'on_interface',
#  'rel_ASA',
#  'delta_kdh',
#  'delta_vol',
#  'delta_chg',
#  'to_proline',
#  'to_glycine',
#  'to_alanine',
#  'from_proline',
#  'from_glycine',
#  'helix',
#  'bend',
#  'turn',
#  'coil',
#  'strand',
#  'active_site',
#  'K1566_pslm_rfa_1',
#  'K1566_pslm_rfa_2',
#  'K1566_pslm_rfa_3',
#  'K1566_pslm_rfa_4',
#  'K1566_pslm_rfa_5',
#  'K1566_pslm_rfa_6',
#  'K1566_pslm_rfa_7',
#  'K1566_pslm_rfa_8',
#  'K1566_pslm_rfa_9',
#  'K1566_pslm_rfa_10',
#  'K1566_pslm_rfa_11']

# %%
assert not [ _ for _ in methods if _ not in s461_dir ]

# %%
s461_df.head()
# Out:
#          uid       uid2 PDB_dir MUT_D_dir  ddG_dir  KORPM_dir  Cartddg_dir  \
# 0   1A0F_11A   1A0F_11A    1A0F     SA11A   -1.800      0.138         1.45
# 1  1BA3_461D  1BA3_457D    1BA3    HA461D   -1.745     -1.065        -4.47
# 2  1BA3_489D  1BA3_485D    1BA3    HA489D    0.287      0.270         0.64
# 3  1BA3_489K  1BA3_485K    1BA3    HA489K   -0.287      0.398         0.86
# 4  1BA3_489M  1BA3_485M    1BA3    HA489M   -0.263     -0.211        -1.08
#
#    FoldXD_dir  Evo_dir  Dynamut2_dir  ...  K1566_pslm_rfa_2_dir  \
# 0        0.48    -0.37         0.545  ...             -1.029995
# 1       -0.86    -0.77         0.160  ...             -0.783987
# 2       -0.13     0.96        -0.193  ...              0.242109
# 3        0.19     1.12         0.190  ...              0.753621
# 4        0.30     1.42        -0.138  ...             -0.005739
#
#    K1566_pslm_rfa_3_dir  K1566_pslm_rfa_4_dir  K1566_pslm_rfa_5_dir  \
# 0             -0.848069             -0.684820             -0.920688
# 1             -0.923162             -1.061914             -1.157944
# 2              0.125597              0.349911              0.696465
# 3              0.667560              1.037881              1.354656
# 4              0.458574              0.606183              0.925346
#
#    K1566_pslm_rfa_6_dir K1566_pslm_rfa_7_dir K1566_pslm_rfa_8_dir  \
# 0             -0.923177            -0.885503            -0.820124
# 1             -1.173859            -1.132453            -1.122098
# 2              0.708697             0.696808             0.725284
# 3              1.390795             1.364180             1.402421
# 4              0.951895             0.958617             0.979611
#
#   K1566_pslm_rfa_9_dir  K1566_pslm_rfa_10_dir K1566_pslm_rfa_11_dir
# 0            -0.820124              -0.820124             -0.819380
# 1            -1.122098              -1.122098             -1.154978
# 2             0.725284               0.725284              0.710356
# 3             1.402421               1.402421              1.401294
# 4             0.979611               0.979611              0.950914
#
# [5 rows x 168 columns]

# %%
#s461_df[['KORPM_dir','korpm_dir']].corr()

# %%
#select_461_df = s461_df[    ["uid", "direction", "uid2", "DDG", "wild_type", "position", "mutation"] + methods]
#select_461_df.head() , select_461_df.shape

# %% [markdown]
# # fit ddMBC/Rose

# %%
aa_codes = [
    str.strip(_)
    for _ in "A, R, N, D, C, E, Q, G, H, I, L, K, M, F, P, S, T, W, Y, V".split(",")
]
fit_df = deepcopy(select_df)
#for _ in aa_codes:    fit_df[_] = 0
fit_df.head()
# Out:
#          uid direction       uid2  DDG chain wild_type  position mutation  \
# 0  1AMQ_191F       dir  1AMQ_180F -1.6     A         C       180        F
# 1  1AMQ_191F       inv  1AMQ_180F  1.6     A         C       180        F
# 2  1AMQ_191S       dir  1AMQ_180S -1.9     A         C       180        S
# 3  1AMQ_191S       inv  1AMQ_180S  1.9     A         C       180        S
# 4  1AMQ_191W       dir  1AMQ_180W -3.9     A         C       180        W
#
#     ACDC-NN  ACDC-NN-Seq  ...      mifst  mpnn_10_00  mpnn_20_00  mpnn_30_00  \
# 0  0.155387     0.000000  ... -15.833597   -4.753813   -5.319994   -4.230467
# 1 -0.179437     0.000000  ...  11.865127    4.274536    5.143872    4.086548
# 2 -0.310174     0.000000  ...  -7.009702   -0.511659   -2.171657   -0.905479
# 3  0.150363     0.000000  ...   7.094869   -0.156843    1.406749    0.149925
# 4  0.175478     0.000235  ... -16.822426   -4.945947   -5.441107   -4.408648
#
#    msa_transformer_mean  msa_transformer_median  mutcomputex  \
# 0            -11.351413              -11.507070    -0.072907
# 1             11.351413               11.507070     0.010589
# 2             -5.473701               -6.148736     0.152491
# 3              5.473701                6.148736    -0.109291
# 4            -13.321842              -13.401335    -0.072507
#
#    stability-oracle  tranception  tranception_weights
# 0            -0.365    -0.030819            -0.029796
# 1             0.110     0.030819             0.029796
# 2            -0.009    -0.015818            -0.015382
# 3             0.108     0.015818             0.015382
# 4            -0.616    -0.035233            -0.037848
#
# [5 rows x 55 columns]

# %%
def encode_mutation(x):
    match x["direction"]:
        case "dir":
            x[x["wild_type"]] -= 1
            x[x["mutation"]] += 1
            return x
        case "inv":
            x[x["wild_type"]] += 1
            x[x["mutation"]] -= 1
            return x

# %%
#fit_df = fit_df.apply(encode_mutation, axis=1)
#fit_df

# %%
rose_df=pandas.read_csv('rose1985.csv',index_col='Parameter')
rose_df
# Out:
#            Rose1985
# Parameter
# A              86.6
# C             132.3
# D              97.8
# E             113.9
# F             194.1
# G              62.9
# H             155.8
# I             158.0
# K             115.5
# L             164.1
# M             172.9
# N             103.3
# P              92.9
# Q             119.2
# R             162.2
# S              85.6
# T             106.5
# V             141.0
# W             224.6
# Y             177.7

# %%
# esmif_df.head()
def rose_delta(x):
    _delta = rose_df["Rose1985"][x["wild_type"]] - rose_df["Rose1985"][x["mutation"]]
    x["rose_delta"] = _delta if x["direction"] == "dir" else -_delta
    return x

# %%
fit_df = fit_df.apply(rose_delta, 
               axis=1
              )
fit_df
# Out:
#            uid direction       uid2  DDG chain wild_type  position mutation  \
# 0    1AMQ_191F       dir  1AMQ_180F -1.6     A         C       180        F
# 1    1AMQ_191F       inv  1AMQ_180F  1.6     A         C       180        F
# 2    1AMQ_191S       dir  1AMQ_180S -1.9     A         C       180        S
# 3    1AMQ_191S       inv  1AMQ_180S  1.9     A         C       180        S
# 4    1AMQ_191W       dir  1AMQ_180W -3.9     A         C       180        W
# ..         ...       ...        ...  ...   ...       ...       ...      ...
# 679   5PTI_35G       inv   5PTI_35G  5.0     A         Y        35        G
# 680   5PTI_43G       dir   5PTI_43G -5.7     A         N        43        G
# 681   5PTI_43G       inv   5PTI_43G  5.7     A         N        43        G
# 682   5PTI_45A       dir   5PTI_45A -6.9     A         F        45        A
# 683   5PTI_45A       inv   5PTI_45A  6.9     A         F        45        A
#
#       ACDC-NN  ACDC-NN-Seq  ...  mpnn_10_00  mpnn_20_00  mpnn_30_00  \
# 0    0.155387     0.000000  ...   -4.753813   -5.319994   -4.230467
# 1   -0.179437     0.000000  ...    4.274536    5.143872    4.086548
# 2   -0.310174     0.000000  ...   -0.511659   -2.171657   -0.905479
# 3    0.150363     0.000000  ...   -0.156843    1.406749    0.149925
# 4    0.175478     0.000235  ...   -4.945947   -5.441107   -4.408648
# ..        ...          ...  ...         ...         ...         ...
# 679  2.394038     3.046156  ...   -5.640223   -5.485600   -5.337170
# 680 -1.785572    -1.548846  ...   -5.804597   -5.387895   -5.760532
# 681  1.418397     1.558716  ...    5.155628    5.263233    4.256405
# 682 -3.439780    -3.219905  ...   -5.616822   -5.456846   -5.437554
# 683  2.607126     3.225423  ...    5.015940    4.813072    5.219217
#
#      msa_transformer_mean  msa_transformer_median  mutcomputex  \
# 0              -11.351413              -11.507070    -0.072907
# 1               11.351413               11.507070     0.010589
# 2               -5.473701               -6.148736     0.152491
# 3                5.473701                6.148736    -0.109291
# 4              -13.321842              -13.401335    -0.072507
# ..                    ...                     ...          ...
# 679             10.376691               10.705666    -0.999981
# 680             -9.403118               -9.475676    -0.957911
# 681              9.403118                9.475676    -0.999996
# 682            -12.561387              -13.084740    -0.915575
# 683             12.561387               13.084740     0.279832
#
#      stability-oracle  tranception  tranception_weights  rose_delta
# 0              -0.365    -0.030819            -0.029796       -61.8
# 1               0.110     0.030819             0.029796        61.8
# 2              -0.009    -0.015818            -0.015382        46.7
# 3               0.108     0.015818             0.015382       -46.7
# 4              -0.616    -0.035233            -0.037848       -92.3
# ..                ...          ...                  ...         ...
# 679            -1.087     0.091949             0.097295      -114.8
# 680            -0.303    -0.055134            -0.062423        40.4
# 681            -0.070     0.055134             0.062423       -40.4
# 682            -0.849    -0.100102            -0.089689       107.5
# 683             0.243     0.100102             0.089689      -107.5
#
# [676 rows x 56 columns]

# %% [markdown]
# ### predict train

# %%
#_mods = methods #["cartesian_ddg"]

mods = {}
X_d = {}
train_score = pandas.DataFrame(index=methods)
for _ in methods:
    X_d[_] = fit_df[[_,'rose_delta']].to_numpy()
    y = fit_df["DDG"].to_numpy()
    mods[_] = LinearRegression(fit_intercept=False).fit(X_d[_], y)
    #mods_no_q[_] = LinearRegression(fit_intercept=False).fit(X_d[_], y) 
    #print(        _, mods[_].intercept_, math.sqrt(mods[_].score(X_d[_], y)), models[_].coef_,    )

# ricorda: il problema è _X 
train_score['Fit_score'] = { _ :  math.sqrt(mods[_].score(X_d[_], y)) for _ in mods.keys()}
#train_score['no_Q'] = { _ :  math.sqrt(mods_no_q[_].score(X_d[_], y)) for _ in mods_no_q.keys()}
train_score.sort_values('Fit_score', ascending=False)
# Out:
#                         Fit_score
# PremPS                   0.848402
# mpnn_30_00               0.707576
# KORPM                    0.699536
# ACDC-NN                  0.696509
# mpnn_20_00               0.696192
# msa_transformer_mean     0.690314
# ACDC-NN-Seq              0.689721
# msa_transformer_median   0.689638
# mifst                    0.686558
# DDGun3D                  0.662290
# mpnn_10_00               0.661600
# ankh                     0.660516
# esm2_15B_half            0.660026
# esm2_650M                0.656497
# esm2_3B                  0.654134
# mif                      0.652531
# tranception_weights      0.652479
# tranception              0.652319
# INPS-Seq                 0.629968
# cartesian_ddg            0.619824
# Cartddg                  0.617567
# stability-oracle         0.592427
# esmif_multimer           0.588642
# esm2_150M                0.571143
# esm1v_2                  0.560058
# FoldX                    0.557313
# esm1v_5                  0.551497
# esm1v_mean               0.551170
# Evo                      0.550127
# esm1v_median             0.549538
# esm1v_3                  0.545898
# esm1v_4                  0.537205
# INPS3D                   0.529721
# esm1v_1                  0.529238
# Dynamut                  0.505704
# mutcomputex              0.494429
# ThermoNet                0.491877
# PoPMuSiC                 0.462485
# MUpro                    0.449539
# MAESTRO                  0.438991
# DUET                     0.438320
# SDM                      0.428494
# Dynamut2                 0.426569
# I-Mutant3.0              0.411662
# I-Mutant3.0-Seq          0.406385
# mCSM                     0.405742
# SAAFEC-SEQ               0.391931

# %%
train_pred=pandas.DataFrame()
for _ in methods:
    train_pred[_] = mods[_].predict(X_d[_])

for _ in ['pearson','spearman']:
    train_rez['ddmbc_rose_' +  _ ] = train_pred.corrwith(select_df['DDG'],method=_)

train_rez['ddmbc_rose_RMSE']= [ math.sqrt(mean_squared_error(select_df['DDG'],train_pred[_m])) for _m in methods]

train_rez.sort_values('plain_pearson',ascending=False)
# Out:
#                         plain_pearson  plain_spearman  plain_RMSE  \
# PremPS                       0.847589        0.834067    1.046586
# KORPM                        0.696388        0.725962    1.338914
# ACDC-NN                      0.693890        0.626436    1.393952
# ACDC-NN-Seq                  0.686184        0.572426    1.389011
# mpnn_30_00                   0.669151        0.709083    2.279188
# mpnn_20_00                   0.657558        0.693754    2.420931
# DDGun3D                      0.649913        0.548728    1.407750
# msa_transformer_mean         0.643642        0.634182    5.342200
# msa_transformer_median       0.643297        0.631633    5.376427
# mifst                        0.640590        0.631589    4.822427
# Cartddg                      0.637411        0.635182    3.405207
# INPS-Seq                     0.630054        0.557573    1.446647
# mpnn_10_00                   0.628000        0.652037    2.604587
# cartesian_ddg                0.624744        0.671402    5.041773
# mif                          0.617599        0.600899    4.240144
# stability-oracle             0.617409        0.629840    1.573712
# ankh                         0.617091        0.620721    5.991157
# esm2_15B_half                0.610243        0.633714    8.924851
# tranception                  0.606895        0.608396    1.823399
# tranception_weights          0.605821        0.608293    1.823430
# esm2_650M                    0.604709        0.614023    5.654608
# esm2_3B                      0.598710        0.606196    8.046196
# INPS3D                       0.561731        0.475367    1.614918
# Evo                          0.554607        0.493212    1.561813
# esmif_multimer               0.547447        0.568851    1.828439
# PoPMuSiC                     0.501536        0.482101    1.750445
# Dynamut                      0.498299        0.448121    1.610121
# ThermoNet                    0.491120        0.418616    1.613678
# MUpro                        0.485768        0.366578    1.879253
# FoldX                        0.485111        0.509246    2.041594
# esm2_150M                    0.466041        0.469239    3.352277
# DUET                         0.432895        0.383564    1.833744
# MAESTRO                      0.432736        0.412807    1.777990
# esm1v_2                      0.429947        0.504154    3.905931
# mutcomputex                  0.420804        0.467437    1.734694
# esm1v_mean                   0.419490        0.480454    3.573549
# esm1v_5                      0.418776        0.490145    3.926035
# esm1v_median                 0.416699        0.477686    3.593399
# esm1v_4                      0.408192        0.449385    3.521259
# esm1v_3                      0.406934        0.439673    3.343533
# I-Mutant3.0-Seq              0.402840        0.403089    1.807418
# mCSM                         0.398768        0.329252    1.921095
# esm1v_1                      0.387076        0.435760    3.643741
# I-Mutant3.0                  0.384281        0.370347    1.838647
# Dynamut2                     0.382145        0.289238    1.888800
# SDM                          0.319628        0.295362    1.993101
# SAAFEC-SEQ                   0.241503        0.180890    2.088778
#
#                         ddmbc_rose_pearson  ddmbc_rose_spearman  \
# PremPS                            0.416583             0.506293
# KORPM                             0.429484             0.503260
# ACDC-NN                           0.329454             0.415291
# ACDC-NN-Seq                       0.337368             0.426674
# mpnn_30_00                        0.470028             0.527657
# mpnn_20_00                        0.441569             0.508794
# DDGun3D                           0.346451             0.399053
# msa_transformer_mean              0.440600             0.483173
# msa_transformer_median            0.440168             0.485668
# mifst                             0.416866             0.470027
# Cartddg                           0.323778             0.354498
# INPS-Seq                          0.325642             0.379778
# mpnn_10_00                        0.435577             0.487980
# cartesian_ddg                     0.285526             0.354787
# mif                               0.358821             0.432621
# stability-oracle                  0.277590             0.330122
# ankh                              0.446473             0.488263
# esm2_15B_half                     0.478638             0.507561
# tranception                       0.409418             0.481278
# tranception_weights               0.413286             0.483887
# esm2_650M                         0.445979             0.495007
# esm2_3B                           0.469430             0.506168
# INPS3D                            0.258344             0.268774
# Evo                               0.253791             0.260823
# esmif_multimer                    0.311295             0.377760
# PoPMuSiC                          0.194119             0.199493
# Dynamut                           0.193855             0.213055
# ThermoNet                         0.221752             0.217506
# MUpro                             0.145070             0.125132
# FoldX                             0.192349             0.198131
# esm2_150M                         0.317070             0.345747
# DUET                              0.174515             0.180551
# MAESTRO                           0.154656             0.151802
# esm1v_2                           0.340764             0.345891
# mutcomputex                       0.256603             0.280339
# esm1v_mean                        0.328977             0.333066
# esm1v_5                           0.331606             0.327851
# esm1v_median                      0.329134             0.333446
# esm1v_4                           0.317440             0.323361
# esm1v_3                           0.312545             0.318504
# I-Mutant3.0-Seq                   0.157145             0.162654
# mCSM                              0.146227             0.151453
# esm1v_1                           0.306733             0.306760
# I-Mutant3.0                       0.157845             0.163906
# Dynamut2                          0.161027             0.152408
# SDM                               0.164466             0.176992
# SAAFEC-SEQ                        0.134289             0.139587
#
#                         ddmbc_rose_RMSE
# PremPS                         0.980401
# KORPM                          1.323487
# ACDC-NN                        1.328953
# ACDC-NN-Seq                    1.341041
# mpnn_30_00                     1.308746
# mpnn_20_00                     1.329522
# DDGun3D                        1.387662
# msa_transformer_mean           1.339995
# msa_transformer_median         1.341187
# mifst                          1.346597
# Cartddg                        1.456691
# INPS-Seq                       1.438360
# mpnn_10_00                     1.388790
# cartesian_ddg                  1.453399
# mif                            1.403432
# stability-oracle               1.492076
# ankh                           1.390559
# esm2_15B_half                  1.391358
# tranception                    1.403770
# tranception_weights            1.403515
# esm2_650M                      1.397073
# esm2_3B                        1.400870
# INPS3D                         1.570878
# Evo                            1.546633
# esmif_multimer                 1.497206
# PoPMuSiC                       1.642099
# Dynamut                        1.597798
# ThermoNet                      1.612536
# MUpro                          1.654386
# FoldX                          1.537782
# esm2_150M                      1.520277
# DUET                           1.664680
# MAESTRO                        1.664073
# esm1v_2                        1.534357
# mutcomputex                    1.609856
# esm1v_mean                     1.545358
# esm1v_5                        1.544958
# esm1v_median                   1.547351
# esm1v_4                        1.562136
# esm1v_3                        1.551763
# I-Mutant3.0-Seq                1.692244
# mCSM                           1.692774
# esm1v_1                        1.571436
# I-Mutant3.0                    1.687863
# Dynamut2                       1.675118
# SDM                            1.673432
# SAAFEC-SEQ                     1.703899

# %%
mods['mutcomputex'].coef_
# Out:
# array([ 0.96109457, -0.01455722])

# %% [markdown]
# ### crossvalidation

# %%
# cv
_cv = pandas.DataFrame(index=["CV_mean", "CV_std"])
for _ in methods:
    fit_rsq = cross_val_score(
        mods[_],
        X_d[_],
        y,
        cv=RepeatedStratifiedKFold(random_state=2411,
            n_splits=5,
            n_repeats=10,
            # shuffle=True,
        ).split(X_d[_], y > 0),
    )
    # fit_rsq
    try:
        fit_rsq_no_nan =  [ _score for _score in fit_rsq if _score > 0.0] #fit_rsq[~numpy.isnan(fit_rsq)]
        _r = numpy.sqrt(fit_rsq_no_nan)
        _cv[_] = [_r.mean(), _r.std()]
    except FloatingPointError:
        print(_, fit_rsq_no_nan)

# %%
train_score = pandas.concat(
    [
        train_score["Fit_score"],
        train_rez["ddmbc_rose_RMSE"],
        _cv.T,
    ],
    axis=1,
)
train_score.sort_values("ddmbc_rose_RMSE")
# Out:
#                         Fit_score  ddmbc_rose_RMSE   CV_mean    CV_std
# PremPS                   0.848402         0.980401  0.844373  0.025981
# mpnn_30_00               0.707576         1.308746  0.698803  0.043831
# KORPM                    0.699536         1.323487  0.691018  0.043610
# ACDC-NN                  0.696509         1.328953  0.685300  0.057280
# mpnn_20_00               0.696192         1.329522  0.685820  0.051165
# msa_transformer_mean     0.690314         1.339995  0.677203  0.062658
# ACDC-NN-Seq              0.689721         1.341041  0.678593  0.059415
# msa_transformer_median   0.689638         1.341187  0.676370  0.063117
# mifst                    0.686558         1.346597  0.674867  0.058753
# DDGun3D                  0.662290         1.387662  0.649932  0.065831
# mpnn_10_00               0.661600         1.388790  0.649907  0.053960
# ankh                     0.660516         1.390559  0.648195  0.057692
# esm2_15B_half            0.660026         1.391358  0.648927  0.053410
# esm2_650M                0.656497         1.397073  0.642707  0.064674
# esm2_3B                  0.654134         1.400870  0.642132  0.057141
# mif                      0.652531         1.403432  0.639870  0.055821
# tranception_weights      0.652479         1.403515  0.637808  0.072712
# tranception              0.652319         1.403770  0.637397  0.073002
# INPS-Seq                 0.629968         1.438360  0.616626  0.061469
# cartesian_ddg            0.619824         1.453399  0.611647  0.084041
# Cartddg                  0.617567         1.456691  0.604173  0.066952
# stability-oracle         0.592427         1.492076  0.575956  0.078005
# esmif_multimer           0.588642         1.497206  0.563945  0.095940
# esm2_150M                0.571143         1.520277  0.550758  0.096590
# esm1v_2                  0.560058         1.534357  0.540145  0.089633
# FoldX                    0.557313         1.537782  0.537086  0.078827
# esm1v_5                  0.551497         1.544958  0.521160  0.112428
# esm1v_mean               0.551170         1.545358  0.527379  0.101917
# Evo                      0.550127         1.546633  0.527719  0.091247
# esm1v_median             0.549538         1.547351  0.525592  0.102648
# esm1v_3                  0.545898         1.551763  0.518838  0.111757
# esm1v_4                  0.537205         1.562136  0.511014  0.108194
# INPS3D                   0.529721         1.570878  0.514826  0.078024
# esm1v_1                  0.529238         1.571436  0.499500  0.118729
# Dynamut                  0.505704         1.597798  0.485986  0.085412
# mutcomputex              0.494429         1.609856  0.474448  0.092095
# ThermoNet                0.491877         1.612536  0.474253  0.085034
# PoPMuSiC                 0.462485         1.642099  0.432870  0.110243
# MUpro                    0.449539         1.654386  0.427354  0.103830
# MAESTRO                  0.438991         1.664073  0.413596  0.110810
# DUET                     0.438320         1.664680  0.412390  0.109466
# SDM                      0.428494         1.673432  0.405521  0.099197
# Dynamut2                 0.426569         1.675118  0.398423  0.123670
# I-Mutant3.0              0.411662         1.687863  0.388171  0.110019
# I-Mutant3.0-Seq          0.406385         1.692244  0.383987  0.103713
# mCSM                     0.405742         1.692774  0.384740  0.111009
# SAAFEC-SEQ               0.391931         1.703899  0.370311  0.106898

# %% [markdown]
# ### fit parameters

# %%
params_df=pandas.DataFrame(index=['Delta','ddmbc_Rose'])
for _ in methods:
    params_df[_]= mods[_].coef_
params_df.T
# Out:
#                             Delta  ddmbc_Rose
# ACDC-NN                  1.560615    0.003236
# ACDC-NN-Seq              1.474562    0.003752
# Cartddg                  0.234815   -0.007416
# DDGun3D                  1.180880    0.007607
# DUET                     0.358874   -0.011749
# Dynamut                  0.801455   -0.005366
# Dynamut2                 0.316419   -0.013225
# Evo                      0.800364   -0.001088
# FoldX                    0.369030   -0.012697
# I-Mutant3.0              0.314322   -0.012820
# I-Mutant3.0-Seq          0.325395   -0.012425
# INPS-Seq                 1.158520    0.000226
# INPS3D                   0.725539   -0.008692
# KORPM                    1.077259   -0.003313
# MAESTRO                  0.458673   -0.012491
# MUpro                    0.346388   -0.012195
# PoPMuSiC                 0.488759   -0.011463
# PremPS                   1.330093    0.001890
# SAAFEC-SEQ               0.151890   -0.014941
# SDM                      0.265751   -0.013265
# ThermoNet                0.974995   -0.001681
# ankh                     0.148810   -0.010107
# cartesian_ddg            0.163688   -0.008426
# esm1v_1                  0.174978   -0.015043
# esm1v_2                  0.177493   -0.014958
# esm1v_3                  0.201159   -0.015162
# esm1v_4                  0.184833   -0.014580
# esm1v_5                  0.172634   -0.014959
# esm1v_mean               0.189708   -0.014905
# esm1v_median             0.187871   -0.014935
# esm2_150M                0.210968   -0.013827
# esm2_15B_half            0.103438   -0.010723
# esm2_3B                  0.112025   -0.011195
# esm2_650M                0.154769   -0.010886
# esmif_multimer          18.370288   -0.011847
# mCSM                     0.244854   -0.013502
# mif                      0.197802   -0.012328
# mifst                    0.187031   -0.011408
# mpnn_10_00               0.313953   -0.011574
# mpnn_20_00               0.349436   -0.011323
# mpnn_30_00               0.373483   -0.011042
# msa_transformer_mean     0.172573   -0.010620
# msa_transformer_median   0.171459   -0.010583
# mutcomputex              0.961095   -0.014557
# stability-oracle         1.450140   -0.006810
# tranception             21.150283   -0.010261
# tranception_weights     21.115751   -0.010382

# %% [markdown]
# ## Test on 461

# %%
select_461_df = deepcopy(
    s461_df[
        ["uid", "code", "wild_type", "position", "mutation", "ddG_dir", "ddG_inv"]
        + ["_".join([_m, "dir"]) for _m in methods]
        # ['_'.join([_m,_]) for _m in methods for _ in ['dir','inv'] ]
    ]
)
select_461_df['direction']='dir'
#for _ in aa_codes:    select_461_df[_]=0
test_461_df=select_461_df.apply(rose_delta,axis=1)
test_461_df
# Out:
#            uid  code wild_type  position mutation  ddG_dir  ddG_inv  \
# 0     1A0F_11A  1A0F         S        11        A   -1.800    1.800
# 1    1BA3_461D  1BA3         H       457        D   -1.745    1.745
# 2    1BA3_489D  1BA3         H       485        D    0.287   -0.287
# 3    1BA3_489K  1BA3         H       485        K   -0.287    0.287
# 4    1BA3_489M  1BA3         H       485        M   -0.263    0.263
# ..         ...   ...       ...       ...      ...      ...      ...
# 456   4HE7_19G  4HE7         A        19        G    0.060   -0.060
# 457   4HE7_19K  4HE7         A        19        K   -0.460    0.460
# 458  5JXB_329G  5JXB         D        25        G   -1.440    1.440
# 459  5JXB_329P  5JXB         D        25        P   -1.440    1.440
# 460  5OAQ_429H  5OAQ         Y       199        H   -2.990    2.990
#
#      ACDC-NN_dir  ACDC-NN-Seq_dir  Cartddg_dir  ...  mpnn_20_00_dir  \
# 0       0.225406         0.041723         1.45  ...       -2.593541
# 1      -0.230352        -0.447964        -4.47  ...       -3.647010
# 2      -0.040138        -0.000271         0.64  ...        1.273386
# 3       0.201055         0.006583         0.86  ...        2.620539
# 4       0.230963         0.079617        -1.08  ...       -0.604758
# ..           ...              ...          ...  ...             ...
# 456    -0.728433        -0.914432        -2.20  ...       -1.105547
# 457    -0.345831         0.026103         0.59  ...        0.482251
# 458    -0.134107        -0.000839        -4.72  ...       -0.347571
# 459     0.134216         0.000536        -8.00  ...       -3.173122
# 460    -1.356237        -1.387815        -8.00  ...       -5.424284
#
#      mpnn_30_00_dir  msa_transformer_mean_dir  msa_transformer_median_dir  \
# 0         -3.121864                 -2.473579                   -2.307158
# 1         -2.449762                 -5.515070                   -5.353736
# 2          1.350624                  0.514193                    0.590200
# 3          2.906657                  3.111199                    3.013958
# 4         -0.753108                 -0.890877                   -0.846117
# ..              ...                       ...                         ...
# 456       -1.041088                  1.028863                    1.028863
# 457        1.065889                  0.065515                    0.065515
# 458       -0.981272                 -8.707702                   -8.724204
# 459       -3.122738                -13.558142                  -13.668578
# 460       -5.238872                -10.953764                  -10.953764
#
#      mutcomputex_dir  stability-oracle_dir  tranception_dir  \
# 0          -0.906813                -0.103        -0.018765
# 1          -0.499039                -0.950        -0.007958
# 2           0.029220                -0.040         0.003863
# 3           0.121793                 0.025         0.003370
# 4          -0.010539                -0.065        -0.002460
# ..               ...                   ...              ...
# 456        -0.037434                -0.155         0.021470
# 457         0.039233                -0.046         0.023775
# 458        -0.177725                 0.026        -0.008806
# 459        -0.171720                -0.164        -0.017972
# 460        -0.686399                -1.019        -0.038128
#
#      tranception_weights_dir  direction  rose_delta
# 0                  -0.018609        dir        -1.0
# 1                  -0.008126        dir        58.0
# 2                   0.003940        dir        58.0
# 3                   0.003423        dir        40.3
# 4                  -0.002355        dir       -17.1
# ..                       ...        ...         ...
# 456                 0.006001        dir        23.7
# 457                -0.000700        dir       -28.9
# 458                -0.007908        dir        34.9
# 459                -0.017719        dir         4.9
# 460                -0.036237        dir        21.9
#
# [461 rows x 56 columns]

# %% [markdown]
# ### predict test

# %%
for _ in methods:
    print( sum(test_461_df[_ + "_dir"].notna()), _ )     
test_461_df.dropna(inplace=True, ignore_index=True)
test_461_df.shape
# Out:
# 461 ACDC-NN
# 461 ACDC-NN-Seq
# 461 Cartddg
# 461 DDGun3D
# 461 DUET
# 461 Dynamut
# 461 Dynamut2
# 461 Evo
# 461 FoldX
# 461 I-Mutant3.0
# 461 I-Mutant3.0-Seq
# 461 INPS-Seq
# 461 INPS3D
# 461 KORPM
# 461 MAESTRO
# 461 MUpro
# 461 PoPMuSiC
# 461 PremPS
# 461 SAAFEC-SEQ
# 461 SDM
# 461 ThermoNet
# 461 ankh
# 461 cartesian_ddg
# 461 esm1v_1
# 461 esm1v_2
# 461 esm1v_3
# 461 esm1v_4
# 461 esm1v_5
# 461 esm1v_mean
# 461 esm1v_median
# 461 esm2_150M
# 461 esm2_15B_half
# 461 esm2_3B
# 461 esm2_650M
# 461 esmif_multimer
# 461 mCSM
# 461 mif
# 461 mifst
# 461 mpnn_10_00
# 461 mpnn_20_00
# 461 mpnn_30_00
# 461 msa_transformer_mean
# 461 msa_transformer_median
# 461 mutcomputex
# 460 stability-oracle
# 461 tranception
# 461 tranception_weights
# (460, 56)

# %%
plain_perf=deepcopy(test_461_df[[_om + '_dir' for _om in methods ]+['rose_delta']]).rename({ _+'_dir' : _ for _ in methods}, axis=1)
plain_perf
#plain_perf.corrwith(test_461_df['ddG_dir'],method='pearson')
# Out:
#       ACDC-NN  ACDC-NN-Seq  Cartddg  DDGun3D   DUET  Dynamut  Dynamut2   Evo  \
# 0    0.225406     0.041723     1.45      0.5 -0.466    0.545     0.545 -0.37
# 1   -0.230352    -0.447964    -4.47     -1.2 -1.757    0.160     0.160 -0.77
# 2   -0.040138    -0.000271     0.64     -0.1 -0.252   -0.193    -0.193  0.96
# 3    0.201055     0.006583     0.86     -0.1  0.358    0.190     0.190  1.12
# 4    0.230963     0.079617    -1.08      0.0  0.287   -0.138    -0.138  1.42
# ..        ...          ...      ...      ...    ...      ...       ...   ...
# 455 -0.728433    -0.914432    -2.20     -0.4 -0.021   -0.133    -0.133 -0.71
# 456 -0.345831     0.026103     0.59     -0.3 -0.518   -0.119    -0.119  0.18
# 457 -0.134107    -0.000839    -4.72     -0.3  0.254    0.694     0.694 -0.53
# 458  0.134216     0.000536    -8.00     -0.2  0.362    0.390     0.390  0.42
# 459 -1.356237    -1.387815    -8.00     -2.4 -1.531   -0.411    -0.411 -4.12
#
#         FoldX  I-Mutant3.0  ...  mpnn_10_00  mpnn_20_00  mpnn_30_00  \
# 0    0.551703        -0.90  ...   -0.958551   -2.593541   -3.121864
# 1   -0.998639        -1.07  ...   -4.696467   -3.647010   -2.449762
# 2   -0.119835         0.12  ...    1.392470    1.273386    1.350624
# 3    0.131499        -0.08  ...    2.524363    2.620539    2.906657
# 4    0.277350         0.24  ...   -0.910601   -0.604758   -0.753108
# ..        ...          ...  ...         ...         ...         ...
# 455  0.031963        -0.90  ...   -1.571091   -1.105547   -1.041088
# 456  0.296079        -0.46  ...    0.625590    0.482251    1.065889
# 457 -0.465159        -0.24  ...   -1.060423   -0.347571   -0.981272
# 458 -0.778776        -0.06  ...   -3.308088   -3.173122   -3.122738
# 459 -3.408590        -1.68  ...   -5.720709   -5.424284   -5.238872
#
#      msa_transformer_mean  msa_transformer_median  mutcomputex  \
# 0               -2.473579               -2.307158    -0.906813
# 1               -5.515070               -5.353736    -0.499039
# 2                0.514193                0.590200     0.029220
# 3                3.111199                3.013958     0.121793
# 4               -0.890877               -0.846117    -0.010539
# ..                    ...                     ...          ...
# 455              1.028863                1.028863    -0.037434
# 456              0.065515                0.065515     0.039233
# 457             -8.707702               -8.724204    -0.177725
# 458            -13.558142              -13.668578    -0.171720
# 459            -10.953764              -10.953764    -0.686399
#
#      stability-oracle  tranception  tranception_weights  rose_delta
# 0              -0.103    -0.018765            -0.018609        -1.0
# 1              -0.950    -0.007958            -0.008126        58.0
# 2              -0.040     0.003863             0.003940        58.0
# 3               0.025     0.003370             0.003423        40.3
# 4              -0.065    -0.002460            -0.002355       -17.1
# ..                ...          ...                  ...         ...
# 455            -0.155     0.021470             0.006001        23.7
# 456            -0.046     0.023775            -0.000700       -28.9
# 457             0.026    -0.008806            -0.007908        34.9
# 458            -0.164    -0.017972            -0.017719         4.9
# 459            -1.019    -0.038128            -0.036237        21.9
#
# [460 rows x 48 columns]

# %% [markdown]
# ## Summary table

# %%
# get pythia data
pythia_nmi=pandas.read_csv('pythia_nmi.csv',index_col=[0])
pythia_nmi
# Out:
#         plain_pearson  test_pearson  delta_pearson  plain_RMSE  test_RMSE  \
# pythia       0.425031      0.616999       0.191968    7.390213   1.216855
#
#         delta_RMSE        type mass_balance
# pythia   -6.173358  struct.PLM            n

# %%
test_pred=pandas.DataFrame()
test_rez= pandas.DataFrame(index=methods)
for _ in methods:
    X_t =  plain_perf[[_,'rose_delta']].to_numpy() # test_461_df[[_+'_dir']+ aa_codes].to_numpy()
    test_pred[_] = mods[_].predict(X_t)
    
    #for _ in ['pearson','spearman']:
    for _ in ['pearson']:
        test_rez['test_' +  _ ] = test_pred.corrwith(test_461_df['ddG_dir'],method=_)
        test_rez['plain_' +  _ ] = plain_perf.corrwith(test_461_df['ddG_dir'],method=_)
        test_rez['delta_' +  _ ] = test_rez['test_'+_] - test_rez['plain_'+_]

test_rez['plain_RMSE']= [ math.sqrt(mean_squared_error(test_461_df['ddG_dir'],plain_perf[_m])) for _m in methods]
test_rez['test_RMSE']= [ math.sqrt(mean_squared_error(test_461_df['ddG_dir'],test_pred[_m])) for _m in methods]
test_rez['delta_RMSE'] = test_rez['plain_RMSE'] - test_rez['test_RMSE']

#test_rez['type']= [method_types[_] for _ in test_rez.index]a
test_rez = test_rez.merge(labelz,left_index=True,right_index=True)
test_rez = pandas.concat([pythia_nmi,test_rez])
test_rez
# Out:
#                         plain_pearson  test_pearson  delta_pearson  \
# pythia                       0.425031      0.616999       0.191968
# ACDC-NN                      0.604194      0.602964      -0.001230
# ACDC-NN-Seq                  0.570004      0.565298      -0.004706
# Cartddg                      0.596848      0.615422       0.018574
# DDGun3D                      0.634511      0.628999      -0.005512
# DUET                         0.593102      0.530999      -0.062103
# Dynamut                      0.504483      0.517453       0.012970
# Dynamut2                     0.504483      0.472093      -0.032390
# Evo                          0.463202      0.468295       0.005093
# FoldX                        0.221282      0.398879       0.177597
# I-Mutant3.0                  0.489675      0.459201      -0.030474
# I-Mutant3.0-Seq              0.441434      0.433550      -0.007884
# INPS-Seq                     0.555353      0.554794      -0.000558
# INPS3D                       0.614779      0.593947      -0.020832
# KORPM                        0.568753      0.594017       0.025264
# MAESTRO                      0.630013      0.574807      -0.055206
# MUpro                        0.395896      0.424427       0.028531
# PoPMuSiC                     0.609484      0.565888      -0.043595
# PremPS                       0.631689      0.624506      -0.007184
# SAAFEC-SEQ                   0.489675      0.425365      -0.064310
# SDM                          0.554517      0.551058      -0.003460
# ThermoNet                    0.554370      0.554412       0.000043
# ankh                         0.434020      0.542109       0.108089
# cartesian_ddg                0.590134      0.600486       0.010352
# esm1v_1                      0.360490      0.499457       0.138967
# esm1v_2                      0.367533      0.501455       0.133921
# esm1v_3                      0.406996      0.515963       0.108967
# esm1v_4                      0.375624      0.502849       0.127225
# esm1v_5                      0.349070      0.484637       0.135567
# esm1v_mean                   0.384502      0.507830       0.123328
# esm1v_median                 0.378573      0.504297       0.125725
# esm2_150M                    0.373128      0.504844       0.131716
# esm2_15B_half                0.331566      0.472932       0.141366
# esm2_3B                      0.362927      0.492806       0.129879
# esm2_650M                    0.423673      0.529914       0.106241
# esmif_multimer               0.370275      0.470022       0.099747
# mCSM                         0.538325      0.458094      -0.080231
# mif                          0.448843      0.568634       0.119792
# mifst                        0.364169      0.519735       0.155566
# mpnn_10_00                   0.339341      0.521116       0.181775
# mpnn_20_00                   0.394938      0.550892       0.155954
# mpnn_30_00                   0.399828      0.545135       0.145307
# msa_transformer_mean         0.301652      0.467062       0.165410
# msa_transformer_median       0.288604      0.453755       0.165152
# mutcomputex                  0.326215      0.500248       0.174033
# stability-oracle             0.618485      0.630406       0.011921
# tranception                  0.236225      0.406511       0.170286
# tranception_weights          0.234860      0.407317       0.172457
#
#                         plain_RMSE  test_RMSE  delta_RMSE         type  \
# pythia                    7.390213   1.216855   -6.173358   struct.PLM
# ACDC-NN                   1.065230   1.185123   -0.119893     transfer
# ACDC-NN-Seq               1.101188   1.218214   -0.117026     transfer
# Cartddg                   3.584026   1.003931    2.580095  biophysical
# DDGun3D                   1.104507   1.135288   -0.030781    untrained
# DUET                      1.060548   1.180457   -0.119909   supervised
# Dynamut                   1.267236   1.239396    0.027840        other
# Dynamut2                  1.267236   1.293028   -0.025792        other
# Evo                       1.273580   1.261779    0.011801  biophysical
# FoldX                     2.229436   1.336322    0.893114  biophysical
# I-Mutant3.0               1.120513   1.240068   -0.119555   supervised
# I-Mutant3.0-Seq           1.164693   1.254776   -0.090082   supervised
# INPS-Seq                  1.103387   1.165314   -0.061926   supervised
# INPS3D                    1.012016   1.043990   -0.031975   supervised
# KORPM                     1.207931   1.139443    0.068488  biophysical
# MAESTRO                   1.042845   1.119910   -0.077065   supervised
# MUpro                     1.167895   1.226440   -0.058545   supervised
# PoPMuSiC                  1.023236   1.102407   -0.079172    potential
# PremPS                    1.027894   1.010993    0.016901   supervised
# SAAFEC-SEQ                1.120513   1.311190   -0.190678   supervised
# SDM                       1.332840   1.227084    0.105756    potential
# ThermoNet                 1.231163   1.221129    0.010034   supervised
# ankh                      5.589172   1.060666    4.528506      seq.PLM
# cartesian_ddg             4.651469   1.056593    3.594877  biophysical
# esm1v_1                   4.096721   1.131152    2.965569      seq.PLM
# esm1v_2                   4.513662   1.130695    3.382967      seq.PLM
# esm1v_3                   4.198247   1.144354    3.053893      seq.PLM
# esm1v_4                   4.298002   1.132846    3.165156      seq.PLM
# esm1v_5                   4.753432   1.159276    3.594157      seq.PLM
# esm1v_mean                4.278728   1.131700    3.147028      seq.PLM
# esm1v_median              4.289048   1.134392    3.154656      seq.PLM
# esm2_150M                 3.539078   1.126202    2.412876      seq.PLM
# esm2_15B_half             6.216605   1.134583    5.082022      seq.PLM
# esm2_3B                   5.659893   1.125638    4.534255      seq.PLM
# esm2_650M                 4.399972   1.085577    3.314396      seq.PLM
# esmif_multimer            1.641912   1.346609    0.295303   struct.PLM
# mCSM                      1.068543   1.254007   -0.185464   supervised
# mif                       4.344658   1.071738    3.272920   struct.PLM
# mifst                     4.996811   1.095391    3.901420   struct.PLM
# mpnn_10_00                2.514741   1.092440    1.422301   struct.PLM
# mpnn_20_00                2.362278   1.067560    1.294718   struct.PLM
# mpnn_30_00                2.343878   1.080932    1.262946   struct.PLM
# msa_transformer_mean      5.835305   1.131992    4.703312      seq.PLM
# msa_transformer_median    5.953550   1.145814    4.807736      seq.PLM
# mutcomputex               1.387862   1.156582    0.231280   struct.PLM
# stability-oracle          1.187882   1.014463    0.173419     transfer
# tranception               1.675464   1.224315    0.451149     seq. PLM
# tranception_weights       1.675691   1.224142    0.451549     seq. PLM
#
#                        mass_balance
# pythia                            n
# ACDC-NN                           y
# ACDC-NN-Seq                       y
# Cartddg                           y
# DDGun3D                           y
# DUET                              y
# Dynamut                           y
# Dynamut2                          y
# Evo                               n
# FoldX                             n
# I-Mutant3.0                       y
# I-Mutant3.0-Seq                   y
# INPS-Seq                          y
# INPS3D                            y
# KORPM                             y
# MAESTRO                           y
# MUpro                             y
# PoPMuSiC                          y
# PremPS                            y
# SAAFEC-SEQ                        y
# SDM                               y
# ThermoNet                         y
# ankh                              n
# cartesian_ddg                     y
# esm1v_1                           n
# esm1v_2                           n
# esm1v_3                           n
# esm1v_4                           n
# esm1v_5                           n
# esm1v_mean                        n
# esm1v_median                      n
# esm2_150M                         n
# esm2_15B_half                     n
# esm2_3B                           n
# esm2_650M                         n
# esmif_multimer                    n
# mCSM                              y
# mif                               n
# mifst                             n
# mpnn_10_00                        n
# mpnn_20_00                        n
# mpnn_30_00                        n
# msa_transformer_mean              n
# msa_transformer_median            n
# mutcomputex                       n
# stability-oracle                  y
# tranception                       n
# tranception_weights               n

# %% [markdown]
# ### Rank by Correlation increase

# %%
test_rez.sort_values( 'delta_pearson',ascending=False) #'test_RMSE')
# Out:
#                         plain_pearson  test_pearson  delta_pearson  \
# pythia                       0.425031      0.616999       0.191968
# mpnn_10_00                   0.339341      0.521116       0.181775
# FoldX                        0.221282      0.398879       0.177597
# mutcomputex                  0.326215      0.500248       0.174033
# tranception_weights          0.234860      0.407317       0.172457
# tranception                  0.236225      0.406511       0.170286
# msa_transformer_mean         0.301652      0.467062       0.165410
# msa_transformer_median       0.288604      0.453755       0.165152
# mpnn_20_00                   0.394938      0.550892       0.155954
# mifst                        0.364169      0.519735       0.155566
# mpnn_30_00                   0.399828      0.545135       0.145307
# esm2_15B_half                0.331566      0.472932       0.141366
# esm1v_1                      0.360490      0.499457       0.138967
# esm1v_5                      0.349070      0.484637       0.135567
# esm1v_2                      0.367533      0.501455       0.133921
# esm2_150M                    0.373128      0.504844       0.131716
# esm2_3B                      0.362927      0.492806       0.129879
# esm1v_4                      0.375624      0.502849       0.127225
# esm1v_median                 0.378573      0.504297       0.125725
# esm1v_mean                   0.384502      0.507830       0.123328
# mif                          0.448843      0.568634       0.119792
# esm1v_3                      0.406996      0.515963       0.108967
# ankh                         0.434020      0.542109       0.108089
# esm2_650M                    0.423673      0.529914       0.106241
# esmif_multimer               0.370275      0.470022       0.099747
# MUpro                        0.395896      0.424427       0.028531
# KORPM                        0.568753      0.594017       0.025264
# Cartddg                      0.596848      0.615422       0.018574
# Dynamut                      0.504483      0.517453       0.012970
# stability-oracle             0.618485      0.630406       0.011921
# cartesian_ddg                0.590134      0.600486       0.010352
# Evo                          0.463202      0.468295       0.005093
# ThermoNet                    0.554370      0.554412       0.000043
# INPS-Seq                     0.555353      0.554794      -0.000558
# ACDC-NN                      0.604194      0.602964      -0.001230
# SDM                          0.554517      0.551058      -0.003460
# ACDC-NN-Seq                  0.570004      0.565298      -0.004706
# DDGun3D                      0.634511      0.628999      -0.005512
# PremPS                       0.631689      0.624506      -0.007184
# I-Mutant3.0-Seq              0.441434      0.433550      -0.007884
# INPS3D                       0.614779      0.593947      -0.020832
# I-Mutant3.0                  0.489675      0.459201      -0.030474
# Dynamut2                     0.504483      0.472093      -0.032390
# PoPMuSiC                     0.609484      0.565888      -0.043595
# MAESTRO                      0.630013      0.574807      -0.055206
# DUET                         0.593102      0.530999      -0.062103
# SAAFEC-SEQ                   0.489675      0.425365      -0.064310
# mCSM                         0.538325      0.458094      -0.080231
#
#                         plain_RMSE  test_RMSE  delta_RMSE         type  \
# pythia                    7.390213   1.216855   -6.173358   struct.PLM
# mpnn_10_00                2.514741   1.092440    1.422301   struct.PLM
# FoldX                     2.229436   1.336322    0.893114  biophysical
# mutcomputex               1.387862   1.156582    0.231280   struct.PLM
# tranception_weights       1.675691   1.224142    0.451549     seq. PLM
# tranception               1.675464   1.224315    0.451149     seq. PLM
# msa_transformer_mean      5.835305   1.131992    4.703312      seq.PLM
# msa_transformer_median    5.953550   1.145814    4.807736      seq.PLM
# mpnn_20_00                2.362278   1.067560    1.294718   struct.PLM
# mifst                     4.996811   1.095391    3.901420   struct.PLM
# mpnn_30_00                2.343878   1.080932    1.262946   struct.PLM
# esm2_15B_half             6.216605   1.134583    5.082022      seq.PLM
# esm1v_1                   4.096721   1.131152    2.965569      seq.PLM
# esm1v_5                   4.753432   1.159276    3.594157      seq.PLM
# esm1v_2                   4.513662   1.130695    3.382967      seq.PLM
# esm2_150M                 3.539078   1.126202    2.412876      seq.PLM
# esm2_3B                   5.659893   1.125638    4.534255      seq.PLM
# esm1v_4                   4.298002   1.132846    3.165156      seq.PLM
# esm1v_median              4.289048   1.134392    3.154656      seq.PLM
# esm1v_mean                4.278728   1.131700    3.147028      seq.PLM
# mif                       4.344658   1.071738    3.272920   struct.PLM
# esm1v_3                   4.198247   1.144354    3.053893      seq.PLM
# ankh                      5.589172   1.060666    4.528506      seq.PLM
# esm2_650M                 4.399972   1.085577    3.314396      seq.PLM
# esmif_multimer            1.641912   1.346609    0.295303   struct.PLM
# MUpro                     1.167895   1.226440   -0.058545   supervised
# KORPM                     1.207931   1.139443    0.068488  biophysical
# Cartddg                   3.584026   1.003931    2.580095  biophysical
# Dynamut                   1.267236   1.239396    0.027840        other
# stability-oracle          1.187882   1.014463    0.173419     transfer
# cartesian_ddg             4.651469   1.056593    3.594877  biophysical
# Evo                       1.273580   1.261779    0.011801  biophysical
# ThermoNet                 1.231163   1.221129    0.010034   supervised
# INPS-Seq                  1.103387   1.165314   -0.061926   supervised
# ACDC-NN                   1.065230   1.185123   -0.119893     transfer
# SDM                       1.332840   1.227084    0.105756    potential
# ACDC-NN-Seq               1.101188   1.218214   -0.117026     transfer
# DDGun3D                   1.104507   1.135288   -0.030781    untrained
# PremPS                    1.027894   1.010993    0.016901   supervised
# I-Mutant3.0-Seq           1.164693   1.254776   -0.090082   supervised
# INPS3D                    1.012016   1.043990   -0.031975   supervised
# I-Mutant3.0               1.120513   1.240068   -0.119555   supervised
# Dynamut2                  1.267236   1.293028   -0.025792        other
# PoPMuSiC                  1.023236   1.102407   -0.079172    potential
# MAESTRO                   1.042845   1.119910   -0.077065   supervised
# DUET                      1.060548   1.180457   -0.119909   supervised
# SAAFEC-SEQ                1.120513   1.311190   -0.190678   supervised
# mCSM                      1.068543   1.254007   -0.185464   supervised
#
#                        mass_balance
# pythia                            n
# mpnn_10_00                        n
# FoldX                             n
# mutcomputex                       n
# tranception_weights               n
# tranception                       n
# msa_transformer_mean              n
# msa_transformer_median            n
# mpnn_20_00                        n
# mifst                             n
# mpnn_30_00                        n
# esm2_15B_half                     n
# esm1v_1                           n
# esm1v_5                           n
# esm1v_2                           n
# esm2_150M                         n
# esm2_3B                           n
# esm1v_4                           n
# esm1v_median                      n
# esm1v_mean                        n
# mif                               n
# esm1v_3                           n
# ankh                              n
# esm2_650M                         n
# esmif_multimer                    n
# MUpro                             y
# KORPM                             y
# Cartddg                           y
# Dynamut                           y
# stability-oracle                  y
# cartesian_ddg                     y
# Evo                               n
# ThermoNet                         y
# INPS-Seq                          y
# ACDC-NN                           y
# SDM                               y
# ACDC-NN-Seq                       y
# DDGun3D                           y
# PremPS                            y
# I-Mutant3.0-Seq                   y
# INPS3D                            y
# I-Mutant3.0                       y
# Dynamut2                          y
# PoPMuSiC                          y
# MAESTRO                           y
# DUET                              y
# SAAFEC-SEQ                        y
# mCSM                              y

# %% [markdown]
# ### Rank improved methods by Correlation

# %%
improved = test_rez['delta_pearson'] > 0.0

# %%
test_rez.sort_values( 'test_pearson',ascending=False) #'test_RMSE')
# Out:
#                         plain_pearson  test_pearson  delta_pearson  \
# stability-oracle             0.618485      0.630406       0.011921
# DDGun3D                      0.634511      0.628999      -0.005512
# PremPS                       0.631689      0.624506      -0.007184
# pythia                       0.425031      0.616999       0.191968
# Cartddg                      0.596848      0.615422       0.018574
# ACDC-NN                      0.604194      0.602964      -0.001230
# cartesian_ddg                0.590134      0.600486       0.010352
# KORPM                        0.568753      0.594017       0.025264
# INPS3D                       0.614779      0.593947      -0.020832
# MAESTRO                      0.630013      0.574807      -0.055206
# mif                          0.448843      0.568634       0.119792
# PoPMuSiC                     0.609484      0.565888      -0.043595
# ACDC-NN-Seq                  0.570004      0.565298      -0.004706
# INPS-Seq                     0.555353      0.554794      -0.000558
# ThermoNet                    0.554370      0.554412       0.000043
# SDM                          0.554517      0.551058      -0.003460
# mpnn_20_00                   0.394938      0.550892       0.155954
# mpnn_30_00                   0.399828      0.545135       0.145307
# ankh                         0.434020      0.542109       0.108089
# DUET                         0.593102      0.530999      -0.062103
# esm2_650M                    0.423673      0.529914       0.106241
# mpnn_10_00                   0.339341      0.521116       0.181775
# mifst                        0.364169      0.519735       0.155566
# Dynamut                      0.504483      0.517453       0.012970
# esm1v_3                      0.406996      0.515963       0.108967
# esm1v_mean                   0.384502      0.507830       0.123328
# esm2_150M                    0.373128      0.504844       0.131716
# esm1v_median                 0.378573      0.504297       0.125725
# esm1v_4                      0.375624      0.502849       0.127225
# esm1v_2                      0.367533      0.501455       0.133921
# mutcomputex                  0.326215      0.500248       0.174033
# esm1v_1                      0.360490      0.499457       0.138967
# esm2_3B                      0.362927      0.492806       0.129879
# esm1v_5                      0.349070      0.484637       0.135567
# esm2_15B_half                0.331566      0.472932       0.141366
# Dynamut2                     0.504483      0.472093      -0.032390
# esmif_multimer               0.370275      0.470022       0.099747
# Evo                          0.463202      0.468295       0.005093
# msa_transformer_mean         0.301652      0.467062       0.165410
# I-Mutant3.0                  0.489675      0.459201      -0.030474
# mCSM                         0.538325      0.458094      -0.080231
# msa_transformer_median       0.288604      0.453755       0.165152
# I-Mutant3.0-Seq              0.441434      0.433550      -0.007884
# SAAFEC-SEQ                   0.489675      0.425365      -0.064310
# MUpro                        0.395896      0.424427       0.028531
# tranception_weights          0.234860      0.407317       0.172457
# tranception                  0.236225      0.406511       0.170286
# FoldX                        0.221282      0.398879       0.177597
#
#                         plain_RMSE  test_RMSE  delta_RMSE         type  \
# stability-oracle          1.187882   1.014463    0.173419     transfer
# DDGun3D                   1.104507   1.135288   -0.030781    untrained
# PremPS                    1.027894   1.010993    0.016901   supervised
# pythia                    7.390213   1.216855   -6.173358   struct.PLM
# Cartddg                   3.584026   1.003931    2.580095  biophysical
# ACDC-NN                   1.065230   1.185123   -0.119893     transfer
# cartesian_ddg             4.651469   1.056593    3.594877  biophysical
# KORPM                     1.207931   1.139443    0.068488  biophysical
# INPS3D                    1.012016   1.043990   -0.031975   supervised
# MAESTRO                   1.042845   1.119910   -0.077065   supervised
# mif                       4.344658   1.071738    3.272920   struct.PLM
# PoPMuSiC                  1.023236   1.102407   -0.079172    potential
# ACDC-NN-Seq               1.101188   1.218214   -0.117026     transfer
# INPS-Seq                  1.103387   1.165314   -0.061926   supervised
# ThermoNet                 1.231163   1.221129    0.010034   supervised
# SDM                       1.332840   1.227084    0.105756    potential
# mpnn_20_00                2.362278   1.067560    1.294718   struct.PLM
# mpnn_30_00                2.343878   1.080932    1.262946   struct.PLM
# ankh                      5.589172   1.060666    4.528506      seq.PLM
# DUET                      1.060548   1.180457   -0.119909   supervised
# esm2_650M                 4.399972   1.085577    3.314396      seq.PLM
# mpnn_10_00                2.514741   1.092440    1.422301   struct.PLM
# mifst                     4.996811   1.095391    3.901420   struct.PLM
# Dynamut                   1.267236   1.239396    0.027840        other
# esm1v_3                   4.198247   1.144354    3.053893      seq.PLM
# esm1v_mean                4.278728   1.131700    3.147028      seq.PLM
# esm2_150M                 3.539078   1.126202    2.412876      seq.PLM
# esm1v_median              4.289048   1.134392    3.154656      seq.PLM
# esm1v_4                   4.298002   1.132846    3.165156      seq.PLM
# esm1v_2                   4.513662   1.130695    3.382967      seq.PLM
# mutcomputex               1.387862   1.156582    0.231280   struct.PLM
# esm1v_1                   4.096721   1.131152    2.965569      seq.PLM
# esm2_3B                   5.659893   1.125638    4.534255      seq.PLM
# esm1v_5                   4.753432   1.159276    3.594157      seq.PLM
# esm2_15B_half             6.216605   1.134583    5.082022      seq.PLM
# Dynamut2                  1.267236   1.293028   -0.025792        other
# esmif_multimer            1.641912   1.346609    0.295303   struct.PLM
# Evo                       1.273580   1.261779    0.011801  biophysical
# msa_transformer_mean      5.835305   1.131992    4.703312      seq.PLM
# I-Mutant3.0               1.120513   1.240068   -0.119555   supervised
# mCSM                      1.068543   1.254007   -0.185464   supervised
# msa_transformer_median    5.953550   1.145814    4.807736      seq.PLM
# I-Mutant3.0-Seq           1.164693   1.254776   -0.090082   supervised
# SAAFEC-SEQ                1.120513   1.311190   -0.190678   supervised
# MUpro                     1.167895   1.226440   -0.058545   supervised
# tranception_weights       1.675691   1.224142    0.451549     seq. PLM
# tranception               1.675464   1.224315    0.451149     seq. PLM
# FoldX                     2.229436   1.336322    0.893114  biophysical
#
#                        mass_balance
# stability-oracle                  y
# DDGun3D                           y
# PremPS                            y
# pythia                            n
# Cartddg                           y
# ACDC-NN                           y
# cartesian_ddg                     y
# KORPM                             y
# INPS3D                            y
# MAESTRO                           y
# mif                               n
# PoPMuSiC                          y
# ACDC-NN-Seq                       y
# INPS-Seq                          y
# ThermoNet                         y
# SDM                               y
# mpnn_20_00                        n
# mpnn_30_00                        n
# ankh                              n
# DUET                              y
# esm2_650M                         n
# mpnn_10_00                        n
# mifst                             n
# Dynamut                           y
# esm1v_3                           n
# esm1v_mean                        n
# esm2_150M                         n
# esm1v_median                      n
# esm1v_4                           n
# esm1v_2                           n
# mutcomputex                       n
# esm1v_1                           n
# esm2_3B                           n
# esm1v_5                           n
# esm2_15B_half                     n
# Dynamut2                          y
# esmif_multimer                    n
# Evo                               n
# msa_transformer_mean              n
# I-Mutant3.0                       y
# mCSM                              y
# msa_transformer_median            n
# I-Mutant3.0-Seq                   y
# SAAFEC-SEQ                        y
# MUpro                             y
# tranception_weights               n
# tranception                       n
# FoldX                             n

# %% [markdown]
# ### Rank improved methods by RMSE

# %%
#improved_rmse =  test_rez["delta_RMSE"] > 0.0
improved_rmse_df= test_rez[ improved  ].sort_values("test_RMSE", ascending=True)
improved_rmse_df
# Out:
#                         plain_pearson  test_pearson  delta_pearson  \
# Cartddg                      0.596848      0.615422       0.018574
# stability-oracle             0.618485      0.630406       0.011921
# cartesian_ddg                0.590134      0.600486       0.010352
# ankh                         0.434020      0.542109       0.108089
# mpnn_20_00                   0.394938      0.550892       0.155954
# mif                          0.448843      0.568634       0.119792
# mpnn_30_00                   0.399828      0.545135       0.145307
# esm2_650M                    0.423673      0.529914       0.106241
# mpnn_10_00                   0.339341      0.521116       0.181775
# mifst                        0.364169      0.519735       0.155566
# esm2_3B                      0.362927      0.492806       0.129879
# esm2_150M                    0.373128      0.504844       0.131716
# esm1v_2                      0.367533      0.501455       0.133921
# esm1v_1                      0.360490      0.499457       0.138967
# esm1v_mean                   0.384502      0.507830       0.123328
# msa_transformer_mean         0.301652      0.467062       0.165410
# esm1v_4                      0.375624      0.502849       0.127225
# esm1v_median                 0.378573      0.504297       0.125725
# esm2_15B_half                0.331566      0.472932       0.141366
# KORPM                        0.568753      0.594017       0.025264
# esm1v_3                      0.406996      0.515963       0.108967
# msa_transformer_median       0.288604      0.453755       0.165152
# mutcomputex                  0.326215      0.500248       0.174033
# esm1v_5                      0.349070      0.484637       0.135567
# pythia                       0.425031      0.616999       0.191968
# ThermoNet                    0.554370      0.554412       0.000043
# tranception_weights          0.234860      0.407317       0.172457
# tranception                  0.236225      0.406511       0.170286
# MUpro                        0.395896      0.424427       0.028531
# Dynamut                      0.504483      0.517453       0.012970
# Evo                          0.463202      0.468295       0.005093
# FoldX                        0.221282      0.398879       0.177597
# esmif_multimer               0.370275      0.470022       0.099747
#
#                         plain_RMSE  test_RMSE  delta_RMSE         type  \
# Cartddg                   3.584026   1.003931    2.580095  biophysical
# stability-oracle          1.187882   1.014463    0.173419     transfer
# cartesian_ddg             4.651469   1.056593    3.594877  biophysical
# ankh                      5.589172   1.060666    4.528506      seq.PLM
# mpnn_20_00                2.362278   1.067560    1.294718   struct.PLM
# mif                       4.344658   1.071738    3.272920   struct.PLM
# mpnn_30_00                2.343878   1.080932    1.262946   struct.PLM
# esm2_650M                 4.399972   1.085577    3.314396      seq.PLM
# mpnn_10_00                2.514741   1.092440    1.422301   struct.PLM
# mifst                     4.996811   1.095391    3.901420   struct.PLM
# esm2_3B                   5.659893   1.125638    4.534255      seq.PLM
# esm2_150M                 3.539078   1.126202    2.412876      seq.PLM
# esm1v_2                   4.513662   1.130695    3.382967      seq.PLM
# esm1v_1                   4.096721   1.131152    2.965569      seq.PLM
# esm1v_mean                4.278728   1.131700    3.147028      seq.PLM
# msa_transformer_mean      5.835305   1.131992    4.703312      seq.PLM
# esm1v_4                   4.298002   1.132846    3.165156      seq.PLM
# esm1v_median              4.289048   1.134392    3.154656      seq.PLM
# esm2_15B_half             6.216605   1.134583    5.082022      seq.PLM
# KORPM                     1.207931   1.139443    0.068488  biophysical
# esm1v_3                   4.198247   1.144354    3.053893      seq.PLM
# msa_transformer_median    5.953550   1.145814    4.807736      seq.PLM
# mutcomputex               1.387862   1.156582    0.231280   struct.PLM
# esm1v_5                   4.753432   1.159276    3.594157      seq.PLM
# pythia                    7.390213   1.216855   -6.173358   struct.PLM
# ThermoNet                 1.231163   1.221129    0.010034   supervised
# tranception_weights       1.675691   1.224142    0.451549     seq. PLM
# tranception               1.675464   1.224315    0.451149     seq. PLM
# MUpro                     1.167895   1.226440   -0.058545   supervised
# Dynamut                   1.267236   1.239396    0.027840        other
# Evo                       1.273580   1.261779    0.011801  biophysical
# FoldX                     2.229436   1.336322    0.893114  biophysical
# esmif_multimer            1.641912   1.346609    0.295303   struct.PLM
#
#                        mass_balance
# Cartddg                           y
# stability-oracle                  y
# cartesian_ddg                     y
# ankh                              n
# mpnn_20_00                        n
# mif                               n
# mpnn_30_00                        n
# esm2_650M                         n
# mpnn_10_00                        n
# mifst                             n
# esm2_3B                           n
# esm2_150M                         n
# esm1v_2                           n
# esm1v_1                           n
# esm1v_mean                        n
# msa_transformer_mean              n
# esm1v_4                           n
# esm1v_median                      n
# esm2_15B_half                     n
# KORPM                             y
# esm1v_3                           n
# msa_transformer_median            n
# mutcomputex                       n
# esm1v_5                           n
# pythia                            n
# ThermoNet                         y
# tranception_weights               n
# tranception                       n
# MUpro                             y
# Dynamut                           y
# Evo                               n
# FoldX                             n
# esmif_multimer                    n

# %% [markdown]
# ### Rank all methods by correlation

# %%
#test_all.columns

# %%
#all_rez= pandas.DataFrame()
#for _ in ['pearson','spearman']:
#    all_rez[_] = test_all.corrwith(test_461_df['ddG_dir'],method=_)

# %%
#def ndx_me(x):
#    if str(x).endswith('_Rose'):
#        return('ddMBC-corrected')
#    return method_types[x]

#all_rez['type']=[ ndx_me(_) for _ in list(all_rez.index)]

# %%
#all_rez[all_rez['pearson'] > 0.45 ].sort_values('pearson',ascending=False)

# %%
#all_rez.sort_values('spearman',ascending=False).to_csv('all_rez.csv')

# %%
#improved_rmse_d#.to_csv('improved.csv')

# %%
test_rez.sort_values('delta_pearson',ascending=False).to_csv("test_rez.csv")
