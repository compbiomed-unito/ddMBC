# %%
import pandas

# %%
labelz=pandas.read_csv('labelled_test_rez.csv', index_col='Method')[['type','mass_balance']]
labelz
# Out:
#                                type mass_balance
# Method
# ACDC-NN                    transfer            y
# ACDC-NN-Seq                transfer            y
# Cartddg                 biophysical            y
# DDGun3D                   untrained            y
# DUET                     supervised            y
# Dynamut                       other            y
# Dynamut2                      other            y
# Evo                     biophysical            n
# FoldX                   biophysical            n
# I-Mutant3.0              supervised            y
# I-Mutant3.0-Seq          supervised            y
# INPS-Seq                 supervised            y
# INPS3D                   supervised            y
# KORPM                   biophysical            y
# MAESTRO                  supervised            y
# MUpro                    supervised            y
# PoPMuSiC                  potential            y
# PremPS                   supervised            y
# ...

# %%
#labelz.to_csv('labelz.csv')
